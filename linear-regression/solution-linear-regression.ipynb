# %% [markdown]
# # 8.
#
# a.
# - i. The F-statistic for the model is significant and therefore there is some relationship between the predictor and the response.
# - ii The R^2 statistic(percentage of variance explained) is only 0.6. Therefore, only 60% of the variance of the response is explained by this simple linear regression. The relationship is strong but it does not appear to be linear.
# - iii The relationship is negative and non-linear.
#
# c. The Residual plot shows considerable trend which indicates a non linear relationship between the response and the predictor

# %%
options(jupyter.plot_mimetypes = 'image/png')

# %%
library(ISLR)

# %%
?Auto
# Out:
# Auto                   package:ISLR                    R Documentation
#
# t
#
# n:
#
#      Gas mileage, horsepower, and other information for 392 vehicles.
#
# e:
#
#      Auto
#
# t:
#
#      A data frame with 392 observations on the following 9 variables.
#
#      ‘mpg’ miles per gallon
#
#      ‘cylinders’ Number of cylinders between 4 and 8
#
#      ‘displacement’ Engine displacement (cu. inches)
#
#      ‘horsepower’ Engine horsepower
#
#      ‘weight’ Vehicle weight (lbs.)
#
#      ‘acceleration’ Time to accelerate from 0 to 60 mph (sec.)
#
#      ‘year’ Model year (modulo 100)
#
#      ‘origin’ Origin of car (1. American, 2. European, 3. Japanese)
#
#      ‘name’ Vehicle name
#
#      The orginal data contained 408 observations but 16 observations
#      with missing values were removed.
#
# e:
#
#      This dataset was taken from the StatLib library which is
#      maintained at Carnegie Mellon University. The dataset was used in
# ...

# %%
fit = lm(mpg~horsepower, Auto)

# %%
summary(fit)
# Out:
# Call:
# lm(formula = mpg ~ horsepower, data = Auto)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -13.5710  -3.2592  -0.3435   2.7630  16.9240
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 39.935861   0.717499   55.66   <2e-16 ***
# horsepower  -0.157845   0.006446  -24.49   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.906 on 390 degrees of freedom
# Multiple R-squared:  0.6059,	Adjusted R-squared:  0.6049
# F-statistic: 599.7 on 1 and 390 DF,  p-value: < 2.2e-16

# %%
plot(fit)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
plot(mpg~horsepower, Auto)
abline(fit, col="red")

# %%
# Predicted Value
predict(fit, data.frame(horsepower=c(98)))
# Out:
#        1
# 24.46708

# %%
# Prediction interval
predict(fit, data.frame(horsepower=c(98)), interval="prediction")
# Out:
#        fit     lwr      upr
# 1 24.46708 14.8094 34.12476

# %%
# Confidence Interval
# Confidenct Interval of the mean value of the response when horsepower=98
predict(fit, data.frame(horsepower=c(98)), interval="confidence")
# Out:
#        fit      lwr      upr
# 1 24.46708 23.97308 24.96108

# %% [markdown]
# # 9.
# c.)
# - i. The F-statistic is significant which indicates that there is a relationship between the response and atleast one of the predictors.
# - ii. displacement, weight, year, origin
# - iii. If all other factors are held constant, the increase in mpg for a 1 year increase in manufacture date will be 0.75
#
# d.) There appears to be non-linearity and heteroscedacity in the residual plot.
#
# e.) Point 14 is a point of high leverage. There don't seem to be any outliers

# %%
pairs(Auto)

# %%
cor(Auto[,1:8])
# Out:
#                     mpg  cylinders displacement horsepower     weight
# mpg           1.0000000 -0.7776175   -0.8051269 -0.7784268 -0.8322442
# cylinders    -0.7776175  1.0000000    0.9508233  0.8429834  0.8975273
# displacement -0.8051269  0.9508233    1.0000000  0.8972570  0.9329944
# horsepower   -0.7784268  0.8429834    0.8972570  1.0000000  0.8645377
# weight       -0.8322442  0.8975273    0.9329944  0.8645377  1.0000000
# acceleration  0.4233285 -0.5046834   -0.5438005 -0.6891955 -0.4168392
# year          0.5805410 -0.3456474   -0.3698552 -0.4163615 -0.3091199
# origin        0.5652088 -0.5689316   -0.6145351 -0.4551715 -0.5850054
#              acceleration       year     origin
# mpg             0.4233285  0.5805410  0.5652088
# cylinders      -0.5046834 -0.3456474 -0.5689316
# displacement   -0.5438005 -0.3698552 -0.6145351
# horsepower     -0.6891955 -0.4163615 -0.4551715
# weight         -0.4168392 -0.3091199 -0.5850054
# acceleration    1.0000000  0.2903161  0.2127458
# ...

# %%
multi_fit = lm(mpg~.-name, Auto)

# %%
summary(multi_fit)
# Out:
# Call:
# lm(formula = mpg ~ . - name, data = Auto)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.5903 -2.1565 -0.1169  1.8690 13.0604
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -17.218435   4.644294  -3.707  0.00024 ***
# cylinders     -0.493376   0.323282  -1.526  0.12780
# displacement   0.019896   0.007515   2.647  0.00844 **
# horsepower    -0.016951   0.013787  -1.230  0.21963
# weight        -0.006474   0.000652  -9.929  < 2e-16 ***
# acceleration   0.080576   0.098845   0.815  0.41548
# year           0.750773   0.050973  14.729  < 2e-16 ***
# origin         1.426141   0.278136   5.127 4.67e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.328 on 384 degrees of freedom
# Multiple R-squared:  0.8215,	Adjusted R-squared:  0.8182
# F-statistic: 252.4 on 7 and 384 DF,  p-value: < 2.2e-16

# %%
plot(multi_fit)

# %%
multi_fit_interaction = lm(mpg~.-name+weight:horsepower+displacement:horsepower+weight:displacement+cylinders:displacement+cylinders:horsepower+cylinders:weight+mpg:horsepower+mpg:displacement+mpg:cylinders, Auto)

# %%
summary(multi_fit_interaction)
# Out:
# Call:
# lm(formula = mpg ~ . - name + weight:horsepower + displacement:horsepower +
#     weight:displacement + cylinders:displacement + cylinders:horsepower +
#     cylinders:weight + mpg:horsepower + mpg:displacement + mpg:cylinders,
#     data = Auto)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.3246 -0.2051 -0.0202  0.2341  2.3225
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)              4.073e+01  1.384e+00  29.426  < 2e-16 ***
# cylinders               -1.250e+01  4.418e-01 -28.287  < 2e-16 ***
# displacement             1.948e-01  9.765e-03  19.948  < 2e-16 ***
# horsepower              -2.133e-01  1.934e-02 -11.027  < 2e-16 ***
# weight                  -3.682e-03  5.565e-04  -6.616 1.27e-10 ***
# acceleration            -4.133e-02  2.071e-02  -1.996  0.04670 *
# year                     3.714e-02  1.219e-02   3.046  0.00249 **
# origin                   1.359e-02  5.556e-02   0.245  0.80689
# ...

# %%
plot(mpg~., Auto)

# %%
plot(mpg~sqrt(displacement), Auto)

# %%
transformed_fit = lm(mpg~.-name-displacement+I((displacement)^(1/2)), Auto)

# %%
summary(transformed_fit)
# Out:
# Call:
# lm(formula = mpg ~ . - name - displacement + I((displacement)^(1/2)),
#     data = Auto)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.7874 -2.1016 -0.0306  1.7594 13.1546
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -1.722e+01  4.819e+00  -3.573 0.000397 ***
# cylinders                2.448e-01  3.365e-01   0.728 0.467328
# horsepower              -4.604e-03  1.348e-02  -0.342 0.732830
# weight                  -5.564e-03  6.921e-04  -8.039 1.13e-14 ***
# acceleration             4.348e-02  1.001e-01   0.434 0.664423
# year                     7.404e-01  5.132e-02  14.428  < 2e-16 ***
# origin                   1.096e+00  2.966e-01   3.696 0.000251 ***
# I((displacement)^(1/2)) -1.699e-01  2.315e-01  -0.734 0.463386
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.356 on 384 degrees of freedom
# ...
